# %%
import io
import os
import boto3
import pandas as pd

# %%
df = pd.read_csv('s3://bucket-fxdata/gbpjpy_last100.csv')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-8d9469953a56> in <module>
# ----> 1 df = pd.read_csv('s3://bucket-fxdata/gbpjpy_last100.csv')
#
# /media/ralph/New Volume/zappa-linux/.zenv/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /media/ralph/New Volume/zappa-linux/.zenv/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     435     # See https://github.com/python/mypy/issues/1297
#     436     fp_or_buf, _, compression, should_close = get_filepath_or_buffer(
# --> 437         filepath_or_buffer, encoding, compression
#     438     )
#     439     kwds["compression"] = compression
#
# /media/ralph/New Volume/zappa-linux/.zenv/lib/python3.6/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     201         if filepath_or_buffer.startswith("s3n://"):
#     202             filepath_or_buffer = filepath_or_buffer.replace("s3n://", "s3://")
# --> 203         fsspec = import_optional_dependency("fsspec")
#     204
#     205         # If botocore is installed we fallback to reading with anon=True
#
# /media/ralph/New Volume/zappa-linux/.zenv/lib/python3.6/site-packages/pandas/compat/_optional.py in import_optional_dependency(name, extra, raise_on_missing, on_version)
#     108     except ImportError:
#     109         if raise_on_missing:
# --> 110             raise ImportError(msg) from None
#     111         else:
#     112             return None
#
# ImportError: Missing optional dependency 'fsspec'.  Use pip or conda to install fsspec.

# %%
df = wr.s3.read_csv('s3://bucket-fxdata/gbpjpy_last100.csv')

# %%
df
# Out:
#            open      high       low     close timeframe  hour  minute   time  \
# 0      134.2230  134.2600  134.2780  134.2130        5m     0       5  00 05
# 1      134.2600  134.2385  134.2825  134.2325        5m     0      10  00 10
# 2      134.2385  134.2425  134.2450  134.2155        5m     0      15  00 15
# 3      134.2425  134.1860  134.2420  134.1605        5m     0      20  00 20
# 4      134.1860  134.1425  134.1915  134.1155        5m     0      25  00 25
# ...         ...       ...       ...       ...       ...   ...     ...    ...
# 32725  140.6055  140.7755  140.4945  140.6860        4h    22       0  22 00
# 32726  140.7080  140.7220  140.4615  140.5145        4h     2       0  02 00
# 32727  140.5230  140.9595  140.5575  140.6550        4h     6       0  06 00
# 32728  140.7040  140.9725  140.5545  140.5975        4h    10       0  10 00
# 32729  140.6925  141.1225  140.6395  140.9955        4h    14       0  14 00
#
#        candle_size_h  candle_size_l  candle_size  days_since  bullish
# 0             0.0370         0.0550         5.50         100        0
# 1             0.0215         0.0225         2.25         100        0
# 2             0.0040         0.0065         0.65         100        0
# 3             0.0565         0.0005         5.65         100        0
# 4             0.0435         0.0055         4.35         100        0
# ...              ...            ...          ...         ...      ...
# 32725         0.1700         0.1110        17.00           1        1
# 32726         0.0140         0.2465        24.65           0        0
# 32727         0.4365         0.0345        43.65           0        1
# 32728         0.2685         0.1495        26.85           0        0
# 32729         0.4300         0.0530        43.00           0        1
#
# [32730 rows x 13 columns]
