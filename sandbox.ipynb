# %%
#import io
#import os
import boto3
import pandas as pd

# %%
#df = pd.read_csv('s3://bucket-fxdata/gbpjpy_last100.csv')

# %%
s3 = boto3.resource(
    service_name='s3',
    region_name='eu-west-2'#,
    #aws_access_key_id='AKIA6BEQIROCKPHVGYMU',
    #aws_secret_access_key='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'
)

# %%
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# bucket-fxdata
# bucket-solvefx
# clayton-analytics.co.uk
# elasticbeanstalk-eu-west-2-964522707844
# elasticbeanstalk-us-east-2-964522707844
# ukhouseindex
# www.clayton-analytics.co.uk
# zappa-duuzqewdn
# zappa-yv3lblskn
# zappa-yv3lblskn3

# %%
for obj in s3.Bucket('bucket-fxdata').objects.all():
    print(obj)
# Out:
# s3.ObjectSummary(bucket_name='bucket-fxdata', key='gbpjpy/')
# s3.ObjectSummary(bucket_name='bucket-fxdata', key='gbpjpy/fiveminute/')
# s3.ObjectSummary(bucket_name='bucket-fxdata', key='gbpjpy/fiveminute/2010_01.csv')
# s3.ObjectSummary(bucket_name='bucket-fxdata', key='gbpjpy/fiveminute/2010_02.csv')
# s3.ObjectSummary(bucket_name='bucket-fxdata', key='gbpjpy/fiveminute/2010_03.csv')
# s3.ObjectSummary(bucket_name='bucket-fxdata', key='gbpjpy/fiveminute/2010_04.csv')
# s3.ObjectSummary(bucket_name='bucket-fxdata', key='gbpjpy/fiveminute/2010_05.csv')
# s3.ObjectSummary(bucket_name='bucket-fxdata', key='gbpjpy/fiveminute/2010_06.csv')
# s3.ObjectSummary(bucket_name='bucket-fxdata', key='gbpjpy/fiveminute/2010_07.csv')
# s3.ObjectSummary(bucket_name='bucket-fxdata', key='gbpjpy/fiveminute/2010_08.csv')
# s3.ObjectSummary(bucket_name='bucket-fxdata', key='gbpjpy/fiveminute/2010_09.csv')
# s3.ObjectSummary(bucket_name='bucket-fxdata', key='gbpjpy/fiveminute/2010_10.csv')
# ...

# %%
obj = s3.Bucket('bucket-fxdata').Object('gbpjpy_last100.csv').get()
foo = pd.read_csv(obj['Body'], index_col=0)

# %%
foo
# Out:
#               high       low     close timeframe  hour  minute   time  \
# open
# 134.2230  134.2600  134.2780  134.2130        5m     0       5  00 05
# 134.2600  134.2385  134.2825  134.2325        5m     0      10  00 10
# 134.2385  134.2425  134.2450  134.2155        5m     0      15  00 15
# 134.2425  134.1860  134.2420  134.1605        5m     0      20  00 20
# 134.1860  134.1425  134.1915  134.1155        5m     0      25  00 25
# ...            ...       ...       ...       ...   ...     ...    ...
# 140.6055  140.7755  140.4945  140.6860        4h    22       0  22 00
# 140.7080  140.7220  140.4615  140.5145        4h     2       0  02 00
# 140.5230  140.9595  140.5575  140.6550        4h     6       0  06 00
# 140.7040  140.9725  140.5545  140.5975        4h    10       0  10 00
# 140.6925  141.1225  140.6395  140.9955        4h    14       0  14 00
#
#           candle_size_h  candle_size_l  candle_size  days_since  bullish
# open
# ...
